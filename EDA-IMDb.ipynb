# %%
import pandas as pd
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

donnees = "C:/Users/Kamar/Desktop/M1 Eco Stat/S1/PYTHON/projet_python/Donnees"

IMDb_movies= pd.read_csv(donnees+"/IMDb_movies.csv", sep=",")
IMDb_names= pd.read_csv(donnees+"/IMDb_names.csv", sep=",")
IMDb_ratings= pd.read_csv(donnees+"/IMDb_ratings.csv", sep=",")
IMDb_title_principals= pd.read_csv(donnees+"/IMDb_title_principals.csv", sep=",")

IMDb_ratings.head()
# Out:
#   imdb_title_id  weighted_average_vote  total_votes  mean_vote  median_vote  \
# 0     tt0000009                    5.9          154        5.9          6.0
# 1     tt0000574                    6.1          589        6.3          6.0
# 2     tt0001892                    5.8          188        6.0          6.0
# 3     tt0002101                    5.2          446        5.3          5.0
# 4     tt0002130                    7.0         2237        6.9          7.0
#
#    votes_10  votes_9  votes_8  votes_7  votes_6  ...  females_30age_avg_vote  \
# 0        12        4       10       43       28  ...                     5.7
# 1        57       18       58      137      139  ...                     6.2
# 2         6        6       17       44       52  ...                     5.8
# 3        15        8       16       62       98  ...                     5.5
# 4       210      225      436      641      344  ...                     7.3
#
# ...

# %%
IMDb_movies.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
# ...

# %%
IMDb_movies.columns.values
# Out:
# array(['imdb_title_id', 'title', 'original_title', 'year',
#        'date_published', 'genre', 'duration', 'country', 'language',
#        'director', 'writer', 'production_company', 'actors',
#        'description', 'avg_vote', 'votes', 'budget', 'usa_gross_income',
#        'worlwide_gross_income', 'metascore', 'reviews_from_users',
#        'reviews_from_critics'], dtype=object)

# %%
IMDb_names.columns.values
# Out:
# array(['imdb_name_id', 'name', 'birth_name', 'height', 'bio',
#        'birth_details', 'date_of_birth', 'place_of_birth',
#        'death_details', 'date_of_death', 'place_of_death',
#        'reason_of_death', 'spouses_string', 'spouses', 'divorces',
#        'spouses_with_children', 'children'], dtype=object)

# %%
IMDb_title_principals.columns.values
# Out:
# array(['imdb_title_id', 'ordering', 'imdb_name_id', 'category', 'job',
#        'characters'], dtype=object)

# %%
IMDb_ratings.columns.values
# Out:
# array(['imdb_title_id', 'weighted_average_vote', 'total_votes',
#        'mean_vote', 'median_vote', 'votes_10', 'votes_9', 'votes_8',
#        'votes_7', 'votes_6', 'votes_5', 'votes_4', 'votes_3', 'votes_2',
#        'votes_1', 'allgenders_0age_avg_vote', 'allgenders_0age_votes',
#        'allgenders_18age_avg_vote', 'allgenders_18age_votes',
#        'allgenders_30age_avg_vote', 'allgenders_30age_votes',
#        'allgenders_45age_avg_vote', 'allgenders_45age_votes',
#        'males_allages_avg_vote', 'males_allages_votes',
#        'males_0age_avg_vote', 'males_0age_votes', 'males_18age_avg_vote',
#        'males_18age_votes', 'males_30age_avg_vote', 'males_30age_votes',
#        'males_45age_avg_vote', 'males_45age_votes',
#        'females_allages_avg_vote', 'females_allages_votes',
#        'females_0age_avg_vote', 'females_0age_votes',
#        'females_18age_avg_vote', 'females_18age_votes',
#        'females_30age_avg_vote', 'females_30age_votes',
# ...

# %%
print(IMDb_title_principals.shape)
print(IMDb_movies.shape)
print(IMDb_names.shape)
print(IMDb_ratings.shape)
# Out:
# (835513, 6)
# (85855, 22)
# (297705, 17)
# (85855, 49)

# %%
import os
file_size_movies = os.path.getsize(donnees+"/IMDb_movies.csv")
file_size_ratings = os.path.getsize(donnees+"/IMDb_ratings.csv")
file_size_princpialTitles = os.path.getsize(donnees+"/IMDb_title_principals.csv")
file_size_names = os.path.getsize(donnees+"/IMDb_names.csv")

print(file_size_movies / 1000000)
print(file_size_ratings / 1000000)
print(file_size_princpialTitles / 1000000)
print(file_size_names / 1000000)
# Out:
# 47.926289
# 17.449108
# 36.638837
# 128.021552

# %%
import matplotlib.pyplot as plt
IMDb_movies.dtypes.value_counts().plot.pie(autopct='%1.0f%%')
plt.axis('off')
plt.title("IMDb_movies")
# Out:
# Text(0.5, 1.0, 'IMDb_movies')

# %%
IMDb_names.dtypes.value_counts().plot.pie(autopct='%1.0f%%')
plt.axis('off')
plt.title("IMDb_names")
# Out:
# Text(0.5, 1.0, 'IMDb_names')

# %%
IMDb_ratings.dtypes.value_counts().plot.pie(autopct='%1.0f%%')
plt.axis('off')
plt.title("IMDb_ratings")
# Out:
# Text(0.5, 1.0, 'IMDb_ratings')

# %%
IMDb_title_principals.dtypes.value_counts().plot.pie(autopct='%1.0f%%')
plt.axis('off')
plt.title("IMDb_title_principals")
# Out:
# Text(0.5, 1.0, 'IMDb_title_principals')

# %% [markdown]
# ### MISSING VALUES

# %%
import seaborn as sns
plt.figure(figsize=(20,10))
sns.heatmap(IMDb_movies.isna(), cbar=False)
plt.title('Valeurs manquantes')
# Out:
# Text(0.5, 1.0, 'Valeurs manquantes')

# %%
(IMDb_movies.isna().sum()/IMDb_movies.shape[0]).sort_values(ascending=True)
# Out:
# imdb_title_id            0.000000
# title                    0.000000
# original_title           0.000000
# year                     0.000000
# date_published           0.000000
# genre                    0.000000
# duration                 0.000000
# votes                    0.000000
# avg_vote                 0.000000
# country                  0.000745
# actors                   0.000804
# director                 0.001013
# language                 0.009702
# writer                   0.018310
# description              0.024635
# production_company       0.051890
# reviews_from_users       0.088486
# reviews_from_critics     0.137406
# worlwide_gross_income    0.638740
# budget                   0.723837
# usa_gross_income         0.821490
# metascore                0.845029
# dtype: float64

# %%
IMDb_movies["genre"]
# Out:
# 0                          Romance
# 1          Biography, Crime, Drama
# 2                            Drama
# 3                   Drama, History
# 4        Adventure, Drama, Fantasy
#                    ...
# 85850                       Comedy
# 85851                Comedy, Drama
# 85852                        Drama
# 85853                Drama, Family
# 85854                        Drama
# Name: genre, Length: 85855, dtype: object

# %%
listGenre = []
for i in IMDb_movies["genre"]:
    array = i.split(",")
    for j in array:
        listGenre.append(j)

liste =list(dict.fromkeys(listGenre))
ListFinal = []
for x in liste:
     l = x.replace(' ', '')
     ListFinal.append(l)
kFinal = list(dict.fromkeys(ListFinal))
kFinal
# Out:
# ['Romance',
#  'Biography',
#  'Crime',
#  'Drama',
#  'History',
#  'Adventure',
#  'Fantasy',
#  'War',
#  'Mystery',
#  'Horror',
#  'Western',
#  'Comedy',
#  'Family',
#  'Action',
#  'Sci-Fi',
#  'Thriller',
#  'Sport',
#  'Animation',
#  'Musical',
#  'Music',
#  'Film-Noir',
#  'Adult',
#  'Documentary',
#  'Reality-TV',
#  'News']

# %%
ListeDistribution = []

for t  in kFinal:
    i = 0
    for m in IMDb_movies["genre"]:
        o = t in m
        
        if o == True:
           i = i +1
    ListeDistribution.append({t:i})
        
ListeDistribution
# Out:
# [{'Romance': 14128},
#  {'Biography': 2377},
#  {'Crime': 11067},
#  {'Drama': 47110},
#  {'History': 2296},
#  {'Adventure': 7590},
#  {'Fantasy': 3812},
#  {'War': 2242},
#  {'Mystery': 5225},
#  {'Horror': 9557},
#  {'Western': 1583},
#  {'Comedy': 29368},
#  {'Family': 3962},
#  {'Action': 12948},
#  {'Sci-Fi': 3608},
#  {'Thriller': 11388},
#  {'Sport': 1064},
#  {'Animation': 2141},
#  {'Musical': 2041},
#  {'Music': 3682},
#  {'Film-Noir': 663},
#  {'Adult': 2},
#  {'Documentary': 2},
#  {'Reality-TV': 3},
#  {'News': 1}]

# %%
listkey = []
listvalue= []
for item in ListeDistribution:
    for key , value in item.items():
        listkey.append(key)
        listvalue.append(value)

import pandas as pd

data = {'genre':  listkey,
        'counting': listvalue,
        
        }

df = pd.DataFrame(data)

print(df)
# Out:
#           genre  counting
# 0       Romance     14128
# 1     Biography      2377
# 2         Crime     11067
# 3         Drama     47110
# 4       History      2296
# 5     Adventure      7590
# 6       Fantasy      3812
# 7           War      2242
# 8       Mystery      5225
# 9        Horror      9557
# 10      Western      1583
# 11       Comedy     29368
# 12       Family      3962
# 13       Action     12948
# 14       Sci-Fi      3608
# 15     Thriller     11388
# 16        Sport      1064
# 17    Animation      2141
# 18      Musical      2041
# 19        Music      3682
# 20    Film-Noir       663
# 21        Adult         2
# 22  Documentary         2
# 23   Reality-TV         3
# 24         News         1

# %%
sns.set_style("whitegrid")
import matplotlib.pyplot as plt
import seaborn as sns 

plt.figure(figsize=(12,10))
splot=sns.barplot(x="genre",y="counting",data=df,ci=None)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.0f'),
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center',
                   xytext = (0, 10), 
                   textcoords = 'offset points')
    
plt.xticks(rotation=90, size=12)
plt.xlabel("Genre", fontsize=15)
plt.ylabel("Counting", fontsize=15)
plt.title("Nombre de films produits par genre", size=18)
plt.plot()
# Out:
# []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   genre     25 non-null     object
#  1   counting  25 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 528.0+ bytes

# %% [raw]
# On obtient donc le graphique ci-dessus, on remarque que le genre de film de plus représenté est Drama, suivi par Comedy et Romance pour 47110, 29368 et 14128 films dans notre base de données respectivement.

# %%
IMDb_movies.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
# ...

# %%
ListeDistributions= []

for t in kFinal:
    rating=0
    
    for indx , m in enumerate(IMDb_movies["genre"]):
        o = t in m
        
        if o == True:
           rating = rating + IMDb_movies["avg_vote"][indx]
    ListeDistributions.append({t:rating})
        
ListeDistributions
# Out:
# [{'Romance': 86741.49999999987},
#  {'Biography': 15745.300000000014},
#  {'Crime': 66697.00000000015},
#  {'Drama': 293772.1000000029},
#  {'History': 15023.600000000017},
#  {'Adventure': 44369.699999999895},
#  {'Fantasy': 21898.59999999998},
#  {'War': 14410.50000000002},
#  {'Mystery': 30425.700000000008},
#  {'Horror': 46192.300000000025},
#  {'Western': 9463.80000000001},
#  {'Comedy': 172245.9999999994},
#  {'Family': 23479.19999999994},
#  {'Action': 72838.6999999996},
#  {'Sci-Fi': 18297.499999999985},
#  {'Thriller': 62335.19999999989},
#  {'Sport': 6435.499999999999},
#  {'Animation': 13662.399999999989},
#  {'Musical': 12750.900000000029},
#  {'Music': 22982.799999999937},
#  {'Film-Noir': 4404.999999999997},
#  {'Adult': 9.1},
#  {'Documentary': 14.6},
#  {'Reality-TV': 11.4},
#  {'News': 6.4}]

# %%
listkeys = []

listvalues= []

listkey = []
listvalue= []
for item in ListeDistribution:
    for key , value in item.items():
        listkey.append(key)
        listvalue.append(value)
        
        
for item in ListeDistributions:
    for key , value in item.items():
        listkeys.append(key)
        listvalues.append(value)
import pandas as pd

datas = {'genre':  listkey,
        'counting': listvalue,
        'avgrating' : listvalues
        
        }

dfs = pd.DataFrame (datas)

print(dfs)

dfs['avg'] = dfs['avgrating']/dfs['counting']
dfs
# Out:
#           genre  counting  avgrating
# 0       Romance     14128    86741.5
# 1     Biography      2377    15745.3
# 2         Crime     11067    66697.0
# 3         Drama     47110   293772.1
# 4       History      2296    15023.6
# 5     Adventure      7590    44369.7
# 6       Fantasy      3812    21898.6
# 7           War      2242    14410.5
# 8       Mystery      5225    30425.7
# 9        Horror      9557    46192.3
# 10      Western      1583     9463.8
# 11       Comedy     29368   172246.0
# 12       Family      3962    23479.2
# 13       Action     12948    72838.7
# 14       Sci-Fi      3608    18297.5
# 15     Thriller     11388    62335.2
# 16        Sport      1064     6435.5
# 17    Animation      2141    13662.4
# 18      Musical      2041    12750.9
# 19        Music      3682    22982.8
# 20    Film-Noir       663     4405.0
# 21        Adult         2        9.1
# 22  Documentary         2       14.6
# 23   Reality-TV         3       11.4
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns 

plt.figure(figsize=(12,10))
splot=sns.barplot(x="genre",y="avg",data=dfs,ci=None)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.1f'),
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 10), 
                   textcoords = 'offset points')
plt.xticks(rotation=90)
plt.xlabel("Genre", fontsize=15)
plt.ylabel("Average", fontsize=15)
plt.title("Répartition des notes de films pour chaque genre", size=18)
plt.plot()
# Out:
# []

# %% [raw]
# On obtient le graphique ci-dessus qui nous montre la répartition moyenne des films selon le genre, on remarque ainsi que le genre le mieux noté est Documentary, suivi par Biography et Film-Noir.
# Cependant, les résultats restent non généralistes étant donné que d’après le graphique précédent on remarque que l’on dispose uniquement de 2 films dont le genre est Documentary, on ne peut donc pas conclure que c’est définitivement le genre le mieux noté homis que cela soit vrai uniquement sur notre base de données.
# On remarque par ailleurs que le genre le plus représenté dans notre base de données, à savoir Drama se distingue d’une note moyenne de 6.2

# %%
IMDb_movies["year"]
# Out:
# 0        1894
# 1        1906
# 2        1911
# 3        1912
# 4        1911
#          ...
# 85850    2020
# 85851    2020
# 85852    2019
# 85853    2019
# 85854    2019
# Name: year, Length: 85855, dtype: object

# %%
listYear = []
for i in IMDb_movies["year"]:
   listYear.append(i)
listYear
# Out:
# [1894,
#  1906,
#  1911,
#  1912,
#  1911,
#  1912,
#  1919,
#  1913,
#  1912,
#  1912,
#  1913,
#  1913,
#  1913,
#  1913,
#  1914,
#  1914,
#  1913,
#  1914,
#  1913,
#  1913,
#  1913,
#  1915,
#  1914,
#  1914,
#  1914,
#  1914,
#  1913,
#  1914,
#  1914,
#  1915,
#  1914,
#  1914,
#  1915,
#  1914,
#  1914,
#  1914,
#  1914,
#  1914,
#  1914,
#  1914,
#  1915,
#  1914,
#  1914,
#  1914,
#  1914,
#  1915,
#  1915,
#  1915,
#  1915,
#  1915,
#  1915,
#  1915,
#  1915,
#  1916,
#  1915,
#  1915,
#  1915,
#  1915,
#  1915,
#  1917,
#  1915,
#  1915,
#  1915,
#  1916,
#  1916,
#  1915,
#  1916,
#  1916,
#  1916,
#  1916,
#  1916,
#  1916,
#  1916,
#  1916,
#  1916,
#  1916,
#  1916,
#  1916,
#  1916,
#  1916,
#  1916,
#  1916,
#  1916,
#  1916,
#  1916,
#  1916,
#  1916,
#  1916,
#  1916,
#  1917,
#  1917,
#  1917,
#  1917,
#  1917,
#  1918,
#  1916,
#  1917,
#  1917,
#  1917,
#  1917,
#  1918,
#  1917,
#  1917,
#  1917,
#  1917,
#  1917,
#  1917,
#  1917,
#  1917,
#  1917,
#  1917,
# ...

# %%
list_obs_annee=[]
for element in IMDb_movies["year"]:
    if element=="TV Movie 2019":
         list_obs_annee.append(2019)
    else:
         list_obs_annee.append(int(element))
   
listYear=list(set(list_obs_annee))
listYear=sorted(listYear)

def compt_annee(liste,annee):
    i=0
    for element in liste:
        if element==annee :
            i=i+1
    return i
 
ListeDistribution2 = []    
for element in listYear:
    compt=compt_annee(list_obs_annee,element)
    ListeDistribution2.append({element:compt})
ListeDistribution2
# Out:
# [{1894: 1},
#  {1906: 1},
#  {1911: 5},
#  {1912: 5},
#  {1913: 13},
#  {1914: 22},
#  {1915: 23},
#  {1916: 35},
#  {1917: 25},
#  {1918: 28},
#  {1919: 48},
#  {1920: 48},
#  {1921: 47},
#  {1922: 42},
#  {1923: 34},
#  {1924: 51},
#  {1925: 68},
#  {1926: 75},
#  {1927: 81},
#  {1928: 84},
#  {1929: 143},
#  {1930: 178},
#  {1931: 231},
#  {1932: 253},
#  {1933: 263},
#  {1934: 289},
#  {1935: 293},
#  {1936: 297},
#  {1937: 312},
#  {1938: 289},
#  {1939: 305},
#  {1940: 308},
#  {1941: 317},
#  {1942: 308},
#  {1943: 274},
#  {1944: 273},
#  {1945: 248},
#  {1946: 274},
#  {1947: 298},
#  {1948: 335},
#  {1949: 338},
#  {1950: 349},
#  {1951: 370},
#  {1952: 394},
#  {1953: 418},
#  {1954: 387},
#  {1955: 411},
#  {1956: 410},
#  {1957: 439},
#  {1958: 457},
#  {1959: 428},
#  {1960: 431},
#  {1961: 442},
#  {1962: 449},
#  {1963: 446},
#  {1964: 481},
#  {1965: 492},
#  {1966: 500},
#  {1967: 545},
#  {1968: 596},
#  {1969: 584},
#  {1970: 624},
#  {1971: 668},
#  {1972: 657},
# ...

# %%
listkey2 = []
listvalue2 = []
for item in ListeDistribution2:
    for key , value in item.items():
        listkey2.append(key)
        listvalue2.append(value)
import pandas as pd

data = {'annee':  listkey2,
        'nb films produits': listvalue2,
        
        }

df = pd.DataFrame (data)

print(df)
# Out:
#      annee  nb films produits
# 0     1894                  1
# 1     1906                  1
# 2     1911                  5
# 3     1912                  5
# 4     1913                 13
# ..     ...                ...
# 107   2016               3138
# 108   2017               3329
# 109   2018               3257
# 110   2019               2842
# 111   2020                789
#
# [112 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns 

plt.figure(figsize=(30,12))
splot=sns.barplot(x="annee",y="nb films produits",data=df,ci=None)

plt.xticks(rotation=90, size=13)
plt.yticks(size=15)
plt.xlabel("Année", fontsize=25)
plt.ylabel("Nombre de films produits", fontsize=25)
plt.title("Évolution du nombre de films produits au cours des années", size=30)
plt.show()

# %% [raw]
# On constate que l’évolution du nombre de films produits a augmenté de manière exponentielle et a notamment doublé durant les deux dernières décennies. Néanmoins, on remarque une chute spectaculaire en 2020, cela est en partie dû à la crise sanitaire mondiale.
# En effet, le COVID-19 a brutalement affecté l'industrie cinématographique mondiale, interrompant la production de films et fermant les cinémas.
# D’après Wikipedia, « L'industrie cinématographique chinoise avait perdu 2 milliards de dollars américains en mars 2020, après avoir fermé tous ses cinémas pendant la période du Nouvel An lunaire qui soutient l'industrie en Asie. L'Amérique du Nord a connu son plus bas week-end au box-office depuis 1998 entre le 13 et le 15 mars. Cineworld, la deuxième plus grande chaîne de cinéma du monde, a fermé ses cinémas en octobre 2020. »
